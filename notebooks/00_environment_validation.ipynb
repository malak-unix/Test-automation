# %% [markdown]
# # Environment Validation
#
# Validate that the selected notebook kernel is the project environment.

# %% [markdown]
# ## Kernel Instructions
#
# Select kernel `Python (sma-test-auto)` or the project interpreter at `.venv\Scripts\python.exe` on Windows.
#
# Linux/macOS users should select `.venv/bin/python`.

# %% [markdown]
# ## Expected Result
#
# `test_auto` imports successfully, and `run_workflow` can be imported without running the workflow.

# %%
import sys
from pathlib import Path

print("Python executable:", sys.executable)
print("Current directory:", Path.cwd())
# Out:
# Python executable: C:\Users\malak\Desktop\TEST_AUTO\sma_test_automation\.venv\Scripts\python.exe
# Current directory: C:\Users\malak\Desktop\TEST_AUTO\sma_test_automation\notebooks

# %%
import test_auto
print("test_auto path:", test_auto.__file__)
# Out:
# test_auto path: C:\Users\malak\Desktop\TEST_AUTO\sma_test_automation\src\test_auto\__init__.py

# %%
from test_auto.graph.workflow import run_workflow
print("run_workflow imported successfully:", callable(run_workflow))
# Out:
# run_workflow imported successfully: True

# %%
import langgraph
import pydantic
import flask
import selenium
import jupyter
import ipykernel

print("Core notebook environment imports OK")
# Out:
# Core notebook environment imports OK

# %%
print("Notebook environment validation completed.")
# Out:
# Notebook environment validation completed.
